# %% [markdown]
# # Lab 4 - Combining Dataframes

# %% [markdown]
# ## NFL Offense Data

# %%
import pandas as pd
import glob as glob
import numpy as np

# %% [markdown]
# 1. Import the NFL week 3, 4, and 5 data and add a week column to dataset and set the value to 3, 4, or 5 for all rows from that week.

# %%
week3 = pd.read_csv("nfloffenseweek3.csv")
week4 = pd.read_csv("nfloffenseweek4.csv")
week5=pd.read_csv("nfloffenseweek5.csv")
week3["Week"] = 3
week4["Week"] = 4
week5["Week"] = 5
week3
week4
week5
# Out:
#     rank                   team  games  points_scored  total_yards  \
# 0      1     Kansas City Chiefs      5            159         1907
# 1      2          Buffalo Bills      5            152         2202
# 2      3          Detroit Lions      5            140         2059
# 3      4       Baltimore Ravens      5            138         1762
# 4      5    Philadelphia Eagles      5            135         2099
# 5      6       Cleveland Browns      5            133         1982
# 6      7       Seattle Seahawks      5            127         1840
# 7      8      Las Vegas Raiders      5            125         1803
# 8      9   Los Angeles Chargers      5            122         1952
# 9     10        Atlanta Falcons      5            118         1657
# 10    11          New York Jets      5            116         1780
# 11    12      Minnesota Vikings      5            115         1805
# 12    13     New Orleans Saints      5            115         1895
# ...

# %% [markdown]
# 2. Combine the weekly dataframes by adding the dataframes together row-wise.

# %%
df= pd.concat([week3,week4,week5], axis =0)
df
# Out:
#     rank                 team  games  points_scored  total_yards  \
# 0      1     Baltimore Ravens      3             99         1141
# 1      2        Detroit Lions      3             95         1227
# 2      3        Buffalo Bills      3             91         1324
# 3      4   Kansas City Chiefs      3             88         1122
# 4      5  Philadelphia Eagles      3             86         1341
# ..   ...                  ...    ...            ...          ...
# 27    28        Chicago Bears      5             86         1370
# 28    29     Los Angeles Rams      5             80         1499
# 29    30  Pittsburgh Steelers      5             77         1479
# 30    31       Denver Broncos      5             75         1718
# 31    32   Indianapolis Colts      5             69         1665
#
#     offensive_plays  yards_per_play  turnovers_lost  fumbles_lost  1st_downs  \
# 0               166             6.9               3             1         55
# ...

# %% [markdown]
# 3. Make up 1 interesting question about this dataset. Answer it.

# %%
#What are the top 5 teams with the highest amount of total yards across weeks 3 and four?
converters = df.groupby(df.team)
converters.total_yards.max().head()
# Out:
# team
# Arizona Cardinals    1761
# Atlanta Falcons      1657
# Baltimore Ravens     1762
# Buffalo Bills        2202
# Carolina Panthers    1357
# Name: total_yards, dtype: int64

# %% [markdown]
# ## World Population Data

# %% [markdown]
# 4. Join the height and weight data to the iq data.
# 5. Join population density to quality of life data.
# 6. Join life expectancy to quality of life data.
# 7. Join iq, life expectancy, quality of life and population density into 1 dataframe.

# %%
height = pd.read_csv("height_weight_data.csv")
iq = pd.read_csv("iq.csv")
height.merge(iq)
# Out:
#         country  male_height  female_height  male_weight  female_weight  \
# 0   Netherlands          184            170         87.9           73.2
# 1    Montenegro          183            170         90.4           75.3
# 2       Estonia          182            168         89.9           73.7
# 3       Denmark          182            169         86.8           70.2
# 4       Iceland          181            168         89.2           72.6
# ..          ...          ...            ...          ...            ...
# 89     Cambodia          165            154         59.7           52.8
# 90  Philippines          165            154         61.8           55.5
# 91   Bangladesh          165            152         57.7           50.5
# 92        Nepal          164            152         60.5           51.6
# 93  Timor-Leste          159            152         53.9           49.0
#
#     male_bmi  female_bmi   iq education_expenditure_per_inhabitant  \
# ...

# %%
pop = pd.read_csv("population_density.csv")
quality = pd.read_csv("quality_of_life.csv")
pop.merge(quality)
# Out:
#        country        area population  pop_per_km_sq  stability  rights  \
# 0    Singapore       719.0     5.45 M         7584.9         83      89
# 1      Bahrain       778.0     1.75 M         2247.2         59      45
# 2     Maldives       300.0     0.54 M         1812.1         64      39
# 3        Malta       320.0     0.52 M         1615.2         86      72
# 4   Bangladesh    147630.0   166.30 M         1126.5         43      26
# ..         ...         ...        ...            ...        ...     ...
# 56     Finland    338450.0     5.54 M           16.4         85     100
# 57      Norway    385203.0     5.41 M           14.0         89      99
# 58      Russia  17098250.0   143.45 M            8.4         47      26
# 59      Canada   9984670.0    38.25 M            3.8         85      92
# 60   Australia   7741220.0    25.74 M            3.3         86      92
#
#     health  safety  climate  costs  popularity
# 0       79     100       45     55          42
# ...

# %%
life= pd.read_csv("life_expectancy.csv")
life.merge(quality)
# Out:
#          country  male_life_expectancy  female_life_expectancy  birth_rate  \
# 0      Hong Kong                  82.9                    88.0         5.8
# 1        Iceland                  81.7                    84.5        12.3
# 2          Japan                  81.6                    87.7         6.8
# 3         Norway                  81.6                    84.9         9.8
# 4      Singapore                  81.5                    86.1         8.5
# ..           ...                   ...                     ...         ...
# 99        Angola                  58.7                    64.4        39.8
# 100     Cameroon                  58.4                    60.9        34.4
# 101  Ivory Coast                  56.9                    59.5        35.2
# 102      Nigeria                  54.1                    56.0        37.0
# 103         Chad                  53.1                    55.9        41.2
#
# ...

# %%
iq = pd.read_csv("iq.csv")
life= pd.read_csv("life_expectancy.csv")
quality = pd.read_csv("quality_of_life.csv")
pop = pd.read_csv("population_density.csv")
df1 = iq.merge(life)
df2 = quality.merge(pop)
df3 = df1.merge(df2)
df3
# Out:
#                  country   iq education_expenditure_per_inhabitant  \
# 0              Singapore  108                                  908
# 1            South Korea  106                                  537
# 2                  Japan  105                                1,258
# 3                  China  104                                   27
# 4            Switzerland  102                                2,539
# 5            Netherlands  102                                1,701
# 6                Finland  101                                1,990
# 7                 Canada  101                                1,661
# 8                Belgium  100                                1,676
# 9                Germany  100                                1,385
# 10        United Kingdom  100                                1,455
# 11           New Zealand  100                                1,283
# 12                Norway   99                                3,527
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55 entries, 0 to 54
# Data columns (total 18 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   country                               55 non-null     object
#  1   iq                                    55 non-null     int64
#  2   education_expenditure_per_inhabitant  54 non-null     object
#  3   daily_max_temp                        55 non-null     float64
#  4   male_life_expectancy                  55 non-null     float64
#  5   female_life_expectancy                55 non-null     float64
#  6   birth_rate                            55 non-null     float64
#  7   death_rate                            55 non-null     float64
#  8   stability                             55 non-null     int64
#  9   rights                                55 non-null     int64
#  10  health                                55 non-null     int64
# ...

# %% [markdown]
# 8. Make up 1 interesting question about one of these datasets and answer it.

# %%
# What is the  maximum iq of countries that have a temperature that is less than 20 degrees celsius
cold = df3[df3['daily_max_temp']<= 20.0]
cold[['country','iq', 'daily_max_temp']].max()
# Out:
# country           United States
# iq                          106
# daily_max_temp             19.2
# dtype: object

# %% [markdown]
# 9. Make up 1 interesting question about one of these datasets and answer it.

# %%
#What is the country with the highest birthrate, and what is its population?
babies = df3[df3['birth_rate']==df3['birth_rate'].max()]
babies[['country','birth_rate', 'population']]
# Out:
#     country  birth_rate population
# 53  Nigeria        37.0   211.40 M

# %% [markdown]
# 10. Make up 1 interesting question about one of these datasets and answer it.

# %%
# Which countries are the males expected to die after age 65?
death = df3[df3['male_life_expectancy']>= 65]
death['country']
# Out:
# 0                Singapore
# 1              South Korea
# 2                    Japan
# 3                    China
# 4              Switzerland
# 5              Netherlands
# 6                  Finland
# 7                   Canada
# 8                  Belgium
# 9                  Germany
# 10          United Kingdom
# 11             New Zealand
# 12                  Norway
# 13                  Sweden
# 14              Luxembourg
# 15                 Denmark
# 16               Australia
# 17                  France
# 18           United States
# 19                   Malta
# 20                   Italy
# 21                   Spain
# 22                  Poland
# 23                  Russia
# 24                 Ukraine
# 25                Portugal
# 26                 Ireland
# 27                 Vietnam
# 28                  Israel
# 29                Malaysia
# 30                  Greece
# 31               Argentina
# 32                 Romania
# 33                  Turkey
# ...
